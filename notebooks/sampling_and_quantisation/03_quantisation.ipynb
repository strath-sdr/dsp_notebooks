# %% [markdown]
# <img src="../strathclyde_banner.png" alt="University of Strathclyde" align="left">

# %% [markdown]
# # 3. Quantisation
# ----

# %% [markdown]
# [⬅️ Previous](02_sampling.ipynb) | |
#
# ----
# ----
